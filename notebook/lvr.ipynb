# %%
from credmark.cmf.ipython import create_cmf
from credmark.cmf.types import Token, Contract, Address, Account, BlockNumber, Records, JoinType
from models.credmark.protocols.dexes.uniswap.univ3_math import tick_to_price, sqrt_price_x_96_to_price, tick_to_sqrt_price_x_96, sqrt_price_x_96_to_tick
from functools import partial

cmf_param = {
    'chain_id': 1,
    'block_number': 17_000_000,  # Remove this line to use the latest block
}

context, _model_loader = create_cmf(cmf_param)

# %% [markdown]
# # Setup pool

# %%
usdc_addr = Token("USDC").address
weth_addr = Token("WETH").address

uniswap_v3_factory = Contract('0x1F98431c8aD98523631AE4a59f267346ea31F984')

# ABI allows us to know function names and parameters, e.g., getPool(address, address, uint).
pool_addr = uniswap_v3_factory.functions.getPool(
    weth_addr.checksum, usdc_addr.checksum, 3000).call()
pool = Contract(pool_addr)

token0 = Token(pool.functions.token0().call())
token1 = Token(pool.functions.token1().call())

pool_fee = pool.functions.fee().call() / 1e6

# %%
def calc_fee(x, fee):
    if x > 0:
        return x * fee
    return 0

# %%
df_swaps = (pd.DataFrame(pool.fetch_events(
    pool.events.Swap, from_block=17_000_000 - 2000, to_block=17_000_000))
    .loc[:, ["blockNumber", "transactionIndex", "logIndex", "amount0", "amount1", "tick", "sqrtPriceX96"]]
    .sort_values(["blockNumber", "transactionIndex", "logIndex"])
    .assign(token_price0=lambda df: df.sqrtPriceX96.apply(partial(sqrt_price_x_96_to_price, token0_decimals=token0.decimals, token1_decimals=token1.decimals)),
            token_price1=lambda df: 1 / df.token0_price,
            amount_scaled0=lambda df: df.amount0.apply(token0.scaled),
            amount_scaled1=lambda df: df.amount1.apply(token1.scaled),

            # When a token is swapped in, only ((1 - fee) * amount) was used, (fee * amount) is the fee
            fee0=lambda df: df.amount_scaled0.apply(
                partial(calc_fee, fee=pool_fee)),
            fee1=lambda df: df.amount_scaled1.apply(
                partial(calc_fee, fee=pool_fee)),

            # when a token is swap out, we calculate the swap price
            swap_price0=lambda df, pool_fee=pool_fee: df.apply(
                lambda r: - r.amount1_scaled * (1 - pool_fee) / r.amount_scaled0 if r.amount0_scaled < 0 else np.nan, axis=1),
            swap_price1=lambda df, pool_fee=pool_fee: df.apply(
                lambda r: - r.amount0_scaled * (1 - pool_fee) / r.amount_scaled1 if r.amount1_scaled < 0 else np.nan, axis=1),

            # let's do when amount0 is negative, it means pool is selling token0, we copy the trade
            copy0=lambda df: df.apply(
                lambda r: r.amount0_scaled * (r.token0_price - r.swap_price0) if r.amount0_scaled < 0 else r.amount1_scaled, axis=1),
            ))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1592909/3337382105.py in ?()
#       1 df_swaps = (pd.DataFrame(pool.fetch_events(
#       2     pool.events.Swap, from_block=17_000_000 - 2000, to_block=17_000_000))
#       3     .loc[:, ["blockNumber", "transactionIndex", "logIndex", "amount0", "amount1", "tick", "sqrtPriceX96"]]
#       4     .sort_values(["blockNumber", "transactionIndex", "logIndex"])
# ----> 5     .assign(token_price0=lambda df: df.sqrtPriceX96.apply(partial(sqrt_price_x_96_to_price, token0_decimals=token0.decimals, token1_decimals=token1.decimals)),
#       6             token_price1=lambda df: 1 / df.token0_price,
#       7             amount_scaled0=lambda df: df.amount0.apply(token0.scaled),
#       8             amount_scaled1=lambda df: df.amount1.apply(token1.scaled),
#
# ~/mambaforge/envs/cmk311/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, **kwargs)
#    5011         """
#    5012         data = self.copy(deep=None)
#    5013
#    5014         for k, v in kwargs.items():
# -> 5015             data[k] = com.apply_if_callable(v, data)
#    5016         return data
#
# ~/mambaforge/envs/cmk311/lib/python3.11/site-packages/pandas/core/common.py in ?(maybe_callable, obj, **kwargs)
#     375     obj : NDFrame
#     376     **kwargs
#     377     """
#     378     if callable(maybe_callable):
# --> 379         return maybe_callable(obj, **kwargs)
#     380
#     381     return maybe_callable
#
# /tmp/ipykernel_1592909/3337382105.py in ?(df)
# ----> 6             token_price1=lambda df: 1 / df.token0_price,
#
# ~/mambaforge/envs/cmk311/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'token0_price'

# %%
# Out:
# [1837968306931908881359176241206735, 201046, 435, 1440, 1440, 0, True]

# %%
# Out:
# (1858.3165550010322, (0.0005381667590700676, 1858.160102136303))

# %%
# When it is a negative, add the fees to it.
token0.scaled(37051716), token1.scaled(20000000000000000),

# (37.162871147999994 / 0.02) - 1858.160102136303, (37.051716 / 0.02) * (1 + 0.003) - 1858.160102136303
# Out:
# (-0.016544736303330865, -0.016544736303330865)

# %% [markdown]
# # Suppport

# %%
# price from SqrtPriceX96 is more precise, price from tick loses precision

end_price_from_tick = 1 / (tick_to_price(201046) *
                           10 ** (token0.decimals - token1.decimals))
end_price_from_sqrt = sqrt_price_x_96_to_price(
    1837968306931908881359176241206735, token0.decimals, token1.decimals)

end_price_from_tick, end_price_from_sqrt
# Out:
# (1858.3165550010322, 0.0005381667590700676)

# %%
# verified that it's post-trade block's sqrtPriceX96 / tick
with context.fork(block_number=16998134) as past_context:
    print(pool.functions.slot0().call())
# Out:
# [1837968306931908881359176241206735, 201046, 435, 1440, 1440, 0, True]

# %%
df_swaps
# Out:
#     blockNumber  transactionIndex  logIndex       amount0  \
# 0      16998134                 3        18     -37051716
# 1      16998137                15        25     -37051708
# 2      16998140                 1        12     -37051700
# 3      16998187               120       186     189586197
# 4      16998446                68       136   -1354917920
# 5      16998526               134       309   -1111539942
# 6      16998696                18        74    1417825000
# 7      16998789                 3        27   -2480693810
# 8      16998862                 0         4     -37050983
# 9      16998867                 4        37     -37050975
# 10     16998870                19        13     -37050967
# 11     16998873                 0         4     -37050959
# 12     16998878                 0         4     -46313688
# 13     16998885               112       235     -16672924
# 14     16998922                 1        23    4289416037
# 15     16999014                 1        17    2168971157
# 16     16999088                93       220   -7772885088
# 17     16999110               105       185    -132017724
# 18     16999163               150       352    -122778933
# 19     16999197                74       138    -169608276
# 10      0.000538   1858.122543      -37.050967        0.020000    0.000000
# 11      0.000538   1858.122149      -37.050959        0.020000    0.000000
# 12      0.000538   1858.121656      -46.313688        0.025000    0.000000
# 13      0.000538   1858.121479      -16.672924        0.009000    0.000000
# 14      0.000538   1858.166984     4289.416037       -2.301516   12.868248
# 15      0.000538   1858.189994     2168.971157       -1.163755    6.506913
# 16      0.000538   1858.107285    -7772.885088        4.195721    0.000000
# 17      0.000538   1858.105881     -132.017724        0.071263    0.000000
# 18      0.000538   1858.104574     -122.778933        0.066276    0.000000
# 19      0.000538   1858.102770     -169.608276        0.091555    0.000000
# 20      0.000538   1858.071612    -2928.217585        1.580673    0.000000
# 21      0.000538   1858.055942    -1472.706856        0.794988    0.000000
# 22      0.000538   1858.033815    -2079.561816        1.122588    0.000000
# 23      0.000538   1859.271616   116662.168901      -62.578764  349.986507
# 24      0.000537   1862.490405   303187.639638     -162.438215  909.562919
# 25      0.000536   1864.177535   158811.269593      -84.973952  476.433809
# 26      0.000536   1865.746844   147656.250000      -78.936343  442.968750
# 27      0.000536   1866.369045    58525.641160      -31.269160  175.576923
# 28      0.000536   1866.867875    46914.062500      -25.057783  140.742188
# 29      0.000536   1866.441277   -40000.000000       21.493190    0.000000
# 30      0.000536   1866.460054     1766.028978       -0.943358    5.298087
#
#         fee1  swap_price0  swap_price1    copy_trade
# 0   0.000060     0.000538          NaN    -37.051716
# 1   0.000060     0.000538          NaN    -37.051708
# 2   0.000060     0.000538          NaN    -37.051700
# 3   0.000000          NaN  1858.160323     -0.101723
# 4   0.002194     0.000538          NaN  -1354.917920
# 5   0.001800     0.000538          NaN  -1111.539942
# 6   0.000000          NaN  1858.142601     -0.760744
# 7   0.004017     0.000538          NaN  -2480.693810
# 8   0.000060     0.000538          NaN    -37.050983
# 9   0.000060     0.000538          NaN    -37.050975
# 10  0.000060     0.000538          NaN    -37.050967
# 11  0.000060     0.000538          NaN    -37.050959
# 12  0.000075     0.000538          NaN    -46.313688
# 13  0.000027     0.000538          NaN    -16.672924
# 14  0.000000          NaN  1858.144231     -2.301516
# 15  0.000000          NaN  1858.178489     -1.163755
# 16  0.012587     0.000538          NaN  -7772.885088
# 17  0.000214     0.000538          NaN   -132.017724
# 18  0.000199     0.000538          NaN   -122.778933
# 19  0.000275     0.000538          NaN   -169.608276
# 20  0.004742     0.000538          NaN  -2928.217585
# 21  0.002385     0.000538          NaN  -1472.706856
# 22  0.003368     0.000538          NaN  -2079.561816
# 23  0.000000          NaN  1858.652612    -62.578764
# 24  0.000000          NaN  1860.880315   -162.438215
# 25  0.000000          NaN  1863.333779    -84.973952
# 26  0.000000          NaN  1864.962024    -78.936343
# 27  0.000000          NaN  1866.057919    -31.269160
# 28  0.000000          NaN  1866.618443    -25.057783
# 29  0.064480     0.000536          NaN -40000.000000
# 30  0.000000          NaN  1866.450666     -0.943358
